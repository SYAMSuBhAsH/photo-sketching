# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
image = cv2.imread("rock.jpg")

gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
invt_img = cv2.bitwise_not(gray_image)
img_smt = cv2.GaussianBlur(invt_img,(21,21),sigmaX=0,sigmaY=0)
def dodgeV2(x,y):
  return cv2.divide(x,255-y,scale=256)

final_img=dodgeV2(gray_image,img_smt)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=480x720 at 0x7F7AE45531D0>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img = cv2.imread("rohit sharma.jpg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges=cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,9,9)
color=cv2.bilateralFilter(img,9,250,250)
cartoon=cv2.bitwise_and(color,color,mask=edges)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F7AE4392FD0>
